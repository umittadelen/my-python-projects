# %%
text = "clarusway" #başta varmı diye sorgular varsa true değeri verir
text.startswith("lc")#                        yoksa false değeri verir
# Out:
# False

# %%
text = "clarusway"  #sonda varmı diye sorgular varsa true değeri verir
text.endswith("ay")#                           yoksa false değeri verir
# Out:
# True

# %%
text1 = "clarusway5" #c=0 l=1 a=2 r=3...
text1.startswith("u", 4)
# Out:
# True

# %%
text = "clarusway"
text = text.replace("c","a") #harfleri değiştirir
print(text)
# Out:
# alarusway

# %%
text = "clArusWay"
text = text.swapcase() #büyük harfleri küçük, küçük harfleri büyük yapar
print(text)
# Out:
# CLaRUSwAY

# %%
text = "clarusway"
text = text.upper() #hepsini büyük yapar
print(text)
# Out:
# CLARUSWAY

# %%
text = "cLarUswaY"
text = text.lower() #hepsini küçük yapar
print(text)
# Out:
# clarusway
